# %% [markdown]
# <a href="https://colab.research.google.com/github/KarbivnychyiVolodymyr/KSWD/blob/main/Karbivnichy_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
from tqdm import tqdm

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import torchvision
import torch
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets

# %%
data_dir = 'data'

train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

print(train_dataset)
type(train_dataset)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 12.7MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 345kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.17MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.74MB/s]
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
# torchvision.datasets.mnist.MNIST

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))
for ax in axs.flatten():
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
import torch
from torchvision import datasets, transforms

class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.mean = mean
        self.std = std

    def __call__ (self, tensor):
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

transform_with_noise = transforms.Compose([
    transforms. ToTensor(),
    AddGaussianNoise (mean=0.0, std=0.1),
    transforms.Normalize((0.5,), (0.5,))
])

# Завантажуємо тренувальний та тестовий датасети з шумом
train_dataset = datasets.MNIST (root='path_to_data', train=True, download=True, transform=transform_with_noise)
test_dataset = datasets. MNIST (root='path_to_data', train=False, download=True, transform=transform_with_noise)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 11.6MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 346kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.21MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.97MB/s]

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))

for ax in axs.flatten():
    img, label = random.choice(train_dataset)

    img = img *0.5 + 0.5

    ax.imshow(np.array(img).squeeze(), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(len(train_dataset)*0.8), int(m*0.2)])

# %%
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):
    def __init__(self, encoded_space_dim):
        super().__init__()

        # Convolutional section
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            nn.ReLU(True)
        )

        # Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        # Linear section
        self.encoder_lin = nn.Sequential(
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            nn.Linear(128, encoded_space_dim)
        )

    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, encoded_space_dim, fc2_input_dim=128):
        super().__init__()

        # Linear section
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 7 * 7 * 16),  # Змінено для 7x7x16
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(16, 7, 7))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(16, 8, 4, stride=2, padding=1),  # 7x7 -> 14x14
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 4, stride=2, padding=1)  # 14x14 -> 28x28
        )

    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)

# Initialize the two networks
encoded_space_dim = 4  # Розмір закодованого простору
encoder = Encoder(encoded_space_dim=encoded_space_dim)
decoder = Decoder(encoded_space_dim=encoded_space_dim)

# %%
img, _ = test_dataset[0]
img = img.unsqueeze(0) # Add the batch dimension in the first axis
print('Original image shape:', img.shape)

# Encode the image
img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
# Define the loss function
loss_fn = torch.nn.MSELoss()

# Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
# Out:
# Selected device: cpu
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=784, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(16, 7, 7))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(8, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label)
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        img = test_dataset[i][0].unsqueeze(0).to(device)
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img  = decoder(encoder(img))
        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Original images')
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 20
history={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
    val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)

    print('\\n EPOCH {}/{} \\t train loss {:.3f} \\t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    plot_ae_outputs(encoder,decoder,n=5)
# Out:
# \t partial train loss (single batch): 2.233044
# \t partial train loss (single batch): 2.218199
# \t partial train loss (single batch): 2.184922
# \t partial train loss (single batch): 2.165903
# \t partial train loss (single batch): 2.137026
# \t partial train loss (single batch): 2.124953
# \t partial train loss (single batch): 2.113252
# \t partial train loss (single batch): 2.102427
# \t partial train loss (single batch): 2.084155
# \t partial train loss (single batch): 2.072675
# \t partial train loss (single batch): 2.060085
# \t partial train loss (single batch): 2.048456
# \t partial train loss (single batch): 2.038978
# \t partial train loss (single batch): 2.037346
# \t partial train loss (single batch): 2.030270
# \t partial train loss (single batch): 2.021631
# \t partial train loss (single batch): 1.994723
# \t partial train loss (single batch): 1.998465
# \t partial train loss (single batch): 1.983317
# \t partial train loss (single batch): 1.967639
# \t partial train loss (single batch): 1.962886
# \t partial train loss (single batch): 1.956340
# \t partial train loss (single batch): 1.949682
# \t partial train loss (single batch): 1.934297
# \t partial train loss (single batch): 1.933554
# \t partial train loss (single batch): 1.916112
# \t partial train loss (single batch): 1.915380
# \t partial train loss (single batch): 1.910388
# \t partial train loss (single batch): 1.900554
# \t partial train loss (single batch): 1.889958
# \t partial train loss (single batch): 1.875601
# \t partial train loss (single batch): 1.872041
# \t partial train loss (single batch): 1.870614
# \t partial train loss (single batch): 1.860110
# \t partial train loss (single batch): 1.847915
# \t partial train loss (single batch): 1.838145
# \t partial train loss (single batch): 1.832499
# \t partial train loss (single batch): 1.831728
# \t partial train loss (single batch): 1.814620
# \t partial train loss (single batch): 1.814422
# \t partial train loss (single batch): 1.798663
# \t partial train loss (single batch): 1.792223
# \t partial train loss (single batch): 1.782907
# \t partial train loss (single batch): 1.777227
# \t partial train loss (single batch): 1.767869
# \t partial train loss (single batch): 1.774002
# \t partial train loss (single batch): 1.759192
# \t partial train loss (single batch): 1.750003
# \t partial train loss (single batch): 1.740261
# \t partial train loss (single batch): 1.730468
# \t partial train loss (single batch): 1.732250
# \t partial train loss (single batch): 1.704233
# \t partial train loss (single batch): 1.705433
# \t partial train loss (single batch): 1.696088
# \t partial train loss (single batch): 1.692471
# \t partial train loss (single batch): 1.677615
# \t partial train loss (single batch): 1.683450
# \t partial train loss (single batch): 1.671278
# \t partial train loss (single batch): 1.669001
# \t partial train loss (single batch): 1.655504
# \t partial train loss (single batch): 1.644928
# \t partial train loss (single batch): 1.643193
# \t partial train loss (single batch): 1.632939
# \t partial train loss (single batch): 1.625250
# \t partial train loss (single batch): 1.616092
# \t partial train loss (single batch): 1.599609
# \t partial train loss (single batch): 1.603573
# \t partial train loss (single batch): 1.593170
# \t partial train loss (single batch): 1.585921
# \t partial train loss (single batch): 1.571364
# \t partial train loss (single batch): 1.568856
# \t partial train loss (single batch): 1.569844
# \t partial train loss (single batch): 1.554176
# \t partial train loss (single batch): 1.548811
# \t partial train loss (single batch): 1.544215
# \t partial train loss (single batch): 1.540222
# \t partial train loss (single batch): 1.530523
# \t partial train loss (single batch): 1.530006
# \t partial train loss (single batch): 1.512609
# \t partial train loss (single batch): 1.507330
# \t partial train loss (single batch): 1.499973
# \t partial train loss (single batch): 1.489115
# \t partial train loss (single batch): 1.483471
# \t partial train loss (single batch): 1.485333
# \t partial train loss (single batch): 1.481027
# \t partial train loss (single batch): 1.472520
# \t partial train loss (single batch): 1.464747
# \t partial train loss (single batch): 1.460491
# \t partial train loss (single batch): 1.453359
# \t partial train loss (single batch): 1.448500
# \t partial train loss (single batch): 1.446460
# \t partial train loss (single batch): 1.433286
# \t partial train loss (single batch): 1.426219
# \t partial train loss (single batch): 1.433405
# \t partial train loss (single batch): 1.427809
# \t partial train loss (single batch): 1.414885
# \t partial train loss (single batch): 1.407349
# \t partial train loss (single batch): 1.395636
# \t partial train loss (single batch): 1.398383
# \t partial train loss (single batch): 1.397962
# \t partial train loss (single batch): 1.390521
# \t partial train loss (single batch): 1.387085
# \t partial train loss (single batch): 1.384262
# \t partial train loss (single batch): 1.368305
# \t partial train loss (single batch): 1.370330
# \t partial train loss (single batch): 1.359016
# \t partial train loss (single batch): 1.355522
# \t partial train loss (single batch): 1.354025
# \t partial train loss (single batch): 1.342471
# \t partial train loss (single batch): 1.341200
# \t partial train loss (single batch): 1.344264
# \t partial train loss (single batch): 1.336120
# \t partial train loss (single batch): 1.330014
# \t partial train loss (single batch): 1.324285
# \t partial train loss (single batch): 1.328027
# \t partial train loss (single batch): 1.315605
# \t partial train loss (single batch): 1.310162
# \t partial train loss (single batch): 1.313500
# \t partial train loss (single batch): 1.305476
# \t partial train loss (single batch): 1.302316
# \t partial train loss (single batch): 1.302487
# \t partial train loss (single batch): 1.304082
# \t partial train loss (single batch): 1.284902
# \t partial train loss (single batch): 1.288855
# \t partial train loss (single batch): 1.280279
# \t partial train loss (single batch): 1.279233
# \t partial train loss (single batch): 1.271442
# \t partial train loss (single batch): 1.272491
# \t partial train loss (single batch): 1.272779
# \t partial train loss (single batch): 1.269610
# \t partial train loss (single batch): 1.267338
# \t partial train loss (single batch): 1.260595
# \t partial train loss (single batch): 1.254417
# \t partial train loss (single batch): 1.246158
# \t partial train loss (single batch): 1.251900
# \t partial train loss (single batch): 1.242363
# \t partial train loss (single batch): 1.239796
# \t partial train loss (single batch): 1.244502
# \t partial train loss (single batch): 1.234934
# \t partial train loss (single batch): 1.233138
# \t partial train loss (single batch): 1.225049
# \t partial train loss (single batch): 1.224365
# \t partial train loss (single batch): 1.225242
# \t partial train loss (single batch): 1.221893
# \t partial train loss (single batch): 1.214670
# \t partial train loss (single batch): 1.214141
# \t partial train loss (single batch): 1.215280
# \t partial train loss (single batch): 1.209249
# \t partial train loss (single batch): 1.205572
# \t partial train loss (single batch): 1.202715
# \t partial train loss (single batch): 1.200922
# \t partial train loss (single batch): 1.196849
# \t partial train loss (single batch): 1.193702
# \t partial train loss (single batch): 1.192668
# \t partial train loss (single batch): 1.187183
# \t partial train loss (single batch): 1.191151
# \t partial train loss (single batch): 1.181919
# \t partial train loss (single batch): 1.178799
# \t partial train loss (single batch): 1.175852
# \t partial train loss (single batch): 1.180842
# \t partial train loss (single batch): 1.170433
# \t partial train loss (single batch): 1.171802
# \t partial train loss (single batch): 1.175295
# \t partial train loss (single batch): 1.168559
# \t partial train loss (single batch): 1.168717
# \t partial train loss (single batch): 1.159791
# \t partial train loss (single batch): 1.161027
# \t partial train loss (single batch): 1.158299
# \t partial train loss (single batch): 1.155766
# \t partial train loss (single batch): 1.150016
# \t partial train loss (single batch): 1.150883
# \t partial train loss (single batch): 1.150814
# \t partial train loss (single batch): 1.153221
# \t partial train loss (single batch): 1.149170
# \t partial train loss (single batch): 1.143275
# \t partial train loss (single batch): 1.143406
# \t partial train loss (single batch): 1.138934
# \t partial train loss (single batch): 1.141553
# \t partial train loss (single batch): 1.134536
# \t partial train loss (single batch): 1.132334
# \t partial train loss (single batch): 1.131294
# \t partial train loss (single batch): 1.127127
# \t partial train loss (single batch): 1.133438
# \t partial train loss (single batch): 1.124852
# \t partial train loss (single batch): 1.121726
# \t partial train loss (single batch): 1.120618
# \t partial train loss (single batch): 1.120981
# \t partial train loss (single batch): 1.117639
# \n EPOCH 1/20 \t train loss 1.503 \t val loss 1.111
# \t partial train loss (single batch): 1.119174
# \t partial train loss (single batch): 1.120985
# \t partial train loss (single batch): 1.118960
# \t partial train loss (single batch): 1.115736
# \t partial train loss (single batch): 1.109648
# \t partial train loss (single batch): 1.109134
# \t partial train loss (single batch): 1.109387
# \t partial train loss (single batch): 1.106849
# \t partial train loss (single batch): 1.106689
# \t partial train loss (single batch): 1.103552
# \t partial train loss (single batch): 1.102168
# \t partial train loss (single batch): 1.102179
# \t partial train loss (single batch): 1.099080
# \t partial train loss (single batch): 1.100562
# \t partial train loss (single batch): 1.103272
# \t partial train loss (single batch): 1.099667
# \t partial train loss (single batch): 1.091922
# \t partial train loss (single batch): 1.094334
# \t partial train loss (single batch): 1.091569
# \t partial train loss (single batch): 1.086750
# \t partial train loss (single batch): 1.087487
# \t partial train loss (single batch): 1.088497
# \t partial train loss (single batch): 1.086604
# \t partial train loss (single batch): 1.085655
# \t partial train loss (single batch): 1.084348
# \t partial train loss (single batch): 1.079119
# \t partial train loss (single batch): 1.083226
# \t partial train loss (single batch): 1.083421
# \t partial train loss (single batch): 1.079523
# \t partial train loss (single batch): 1.077596
# \t partial train loss (single batch): 1.074014
# \t partial train loss (single batch): 1.075659
# \t partial train loss (single batch): 1.076147
# \t partial train loss (single batch): 1.075007
# \t partial train loss (single batch): 1.070620
# \t partial train loss (single batch): 1.068140
# \t partial train loss (single batch): 1.069288
# \t partial train loss (single batch): 1.069610
# \t partial train loss (single batch): 1.064168
# \t partial train loss (single batch): 1.068576
# \t partial train loss (single batch): 1.064662
# \t partial train loss (single batch): 1.065620
# \t partial train loss (single batch): 1.063451
# \t partial train loss (single batch): 1.061997
# \t partial train loss (single batch): 1.062442
# \t partial train loss (single batch): 1.065061
# \t partial train loss (single batch): 1.061502
# \t partial train loss (single batch): 1.060867
# \t partial train loss (single batch): 1.059262
# \t partial train loss (single batch): 1.057432
# \t partial train loss (single batch): 1.059109
# \t partial train loss (single batch): 1.049788
# \t partial train loss (single batch): 1.053814
# \t partial train loss (single batch): 1.051175
# \t partial train loss (single batch): 1.053755
# \t partial train loss (single batch): 1.047601
# \t partial train loss (single batch): 1.052255
# \t partial train loss (single batch): 1.052157
# \t partial train loss (single batch): 1.052942
# \t partial train loss (single batch): 1.046840
# \t partial train loss (single batch): 1.045299
# \t partial train loss (single batch): 1.047989
# \t partial train loss (single batch): 1.046486
# \t partial train loss (single batch): 1.046857
# \t partial train loss (single batch): 1.043866
# \t partial train loss (single batch): 1.039290
# \t partial train loss (single batch): 1.044187
# \t partial train loss (single batch): 1.041079
# \t partial train loss (single batch): 1.039975
# \t partial train loss (single batch): 1.036580
# \t partial train loss (single batch): 1.038079
# \t partial train loss (single batch): 1.039923
# \t partial train loss (single batch): 1.036407
# \t partial train loss (single batch): 1.036584
# \t partial train loss (single batch): 1.037209
# \t partial train loss (single batch): 1.035534
# \t partial train loss (single batch): 1.034593
# \t partial train loss (single batch): 1.035045
# \t partial train loss (single batch): 1.032698
# \t partial train loss (single batch): 1.032631
# \t partial train loss (single batch): 1.030811
# \t partial train loss (single batch): 1.027758
# \t partial train loss (single batch): 1.028168
# \t partial train loss (single batch): 1.029164
# \t partial train loss (single batch): 1.030783
# \t partial train loss (single batch): 1.028109
# \t partial train loss (single batch): 1.027938
# \t partial train loss (single batch): 1.027005
# \t partial train loss (single batch): 1.025274
# \t partial train loss (single batch): 1.026785
# \t partial train loss (single batch): 1.026826
# \t partial train loss (single batch): 1.023522
# \t partial train loss (single batch): 1.022230
# \t partial train loss (single batch): 1.026218
# \t partial train loss (single batch): 1.027411
# \t partial train loss (single batch): 1.019717
# \t partial train loss (single batch): 1.018517
# \t partial train loss (single batch): 1.016189
# \t partial train loss (single batch): 1.019042
# \t partial train loss (single batch): 1.023283
# \t partial train loss (single batch): 1.020073
# \t partial train loss (single batch): 1.021062
# \t partial train loss (single batch): 1.018950
# \t partial train loss (single batch): 1.013189
# \t partial train loss (single batch): 1.017373
# \t partial train loss (single batch): 1.012885
# \t partial train loss (single batch): 1.016362
# \t partial train loss (single batch): 1.015484
# \t partial train loss (single batch): 1.009616
# \t partial train loss (single batch): 1.010774
# \t partial train loss (single batch): 1.013554
# \t partial train loss (single batch): 1.014147
# \t partial train loss (single batch): 1.011871
# \t partial train loss (single batch): 1.008188
# \t partial train loss (single batch): 1.014184
# \t partial train loss (single batch): 1.007384
# \t partial train loss (single batch): 1.005562
# \t partial train loss (single batch): 1.009252
# \t partial train loss (single batch): 1.008639
# \t partial train loss (single batch): 1.007722
# \t partial train loss (single batch): 1.010018
# \t partial train loss (single batch): 1.012948
# \t partial train loss (single batch): 1.004143
# \t partial train loss (single batch): 1.006646
# \t partial train loss (single batch): 1.004078
# \t partial train loss (single batch): 1.005518
# \t partial train loss (single batch): 1.003561
# \t partial train loss (single batch): 1.004416
# \t partial train loss (single batch): 1.006529
# \t partial train loss (single batch): 1.004872
# \t partial train loss (single batch): 1.006775
# \t partial train loss (single batch): 1.004703
# \t partial train loss (single batch): 1.001256
# \t partial train loss (single batch): 0.998894
# \t partial train loss (single batch): 1.003618
# \t partial train loss (single batch): 0.999557
# \t partial train loss (single batch): 0.998523
# \t partial train loss (single batch): 1.004568
# \t partial train loss (single batch): 0.999520
# \t partial train loss (single batch): 1.000426
# \t partial train loss (single batch): 0.998117
# \t partial train loss (single batch): 0.998755
# \t partial train loss (single batch): 0.998607
# \t partial train loss (single batch): 1.000920
# \t partial train loss (single batch): 0.997252
# \t partial train loss (single batch): 0.998895
# \t partial train loss (single batch): 0.999454
# \t partial train loss (single batch): 0.997699
# \t partial train loss (single batch): 0.995702
# \t partial train loss (single batch): 0.996911
# \t partial train loss (single batch): 0.996642
# \t partial train loss (single batch): 0.998452
# \t partial train loss (single batch): 0.994000
# \t partial train loss (single batch): 0.996066
# \t partial train loss (single batch): 0.993562
# \t partial train loss (single batch): 0.998606
# \t partial train loss (single batch): 0.992451
# \t partial train loss (single batch): 0.992941
# \t partial train loss (single batch): 0.989707
# \t partial train loss (single batch): 0.996038
# \t partial train loss (single batch): 0.988768
# \t partial train loss (single batch): 0.991762
# \t partial train loss (single batch): 0.994999
# \t partial train loss (single batch): 0.991851
# \t partial train loss (single batch): 0.993912
# \t partial train loss (single batch): 0.989001
# \t partial train loss (single batch): 0.992787
# \t partial train loss (single batch): 0.990674
# \t partial train loss (single batch): 0.992281
# \t partial train loss (single batch): 0.986287
# \t partial train loss (single batch): 0.989247
# \t partial train loss (single batch): 0.992147
# \t partial train loss (single batch): 0.992639
# \t partial train loss (single batch): 0.991652
# \t partial train loss (single batch): 0.991269
# \t partial train loss (single batch): 0.988056
# \t partial train loss (single batch): 0.987844
# \t partial train loss (single batch): 0.991729
# \t partial train loss (single batch): 0.987719
# \t partial train loss (single batch): 0.988940
# \t partial train loss (single batch): 0.986440
# \t partial train loss (single batch): 0.985259
# \t partial train loss (single batch): 0.991290
# \t partial train loss (single batch): 0.987571
# \t partial train loss (single batch): 0.985430
# \t partial train loss (single batch): 0.984486
# \t partial train loss (single batch): 0.985335
# \t partial train loss (single batch): 0.983081
# \n EPOCH 2/20 \t train loss 1.032 \t val loss 0.985
# \t partial train loss (single batch): 0.986234
# \t partial train loss (single batch): 0.987327
# \t partial train loss (single batch): 0.985599
# \t partial train loss (single batch): 0.986754
# \t partial train loss (single batch): 0.982269
# \t partial train loss (single batch): 0.984223
# \t partial train loss (single batch): 0.985085
# \t partial train loss (single batch): 0.983921
# \t partial train loss (single batch): 0.984934
# \t partial train loss (single batch): 0.983241
# \t partial train loss (single batch): 0.980331
# \t partial train loss (single batch): 0.982461
# \t partial train loss (single batch): 0.981949
# \t partial train loss (single batch): 0.985477
# \t partial train loss (single batch): 0.985533
# \t partial train loss (single batch): 0.984591
# \t partial train loss (single batch): 0.978491
# \t partial train loss (single batch): 0.983321
# \t partial train loss (single batch): 0.982561
# \t partial train loss (single batch): 0.978885
# \t partial train loss (single batch): 0.981126
# \t partial train loss (single batch): 0.980966
# \t partial train loss (single batch): 0.979695
# \t partial train loss (single batch): 0.979215
# \t partial train loss (single batch): 0.980122
# \t partial train loss (single batch): 0.978378
# \t partial train loss (single batch): 0.981403
# \t partial train loss (single batch): 0.980883
# \t partial train loss (single batch): 0.980148
# \t partial train loss (single batch): 0.978600
# \t partial train loss (single batch): 0.976042
# \t partial train loss (single batch): 0.978633
# \t partial train loss (single batch): 0.979850
# \t partial train loss (single batch): 0.978868
# \t partial train loss (single batch): 0.977934
# \t partial train loss (single batch): 0.975776
# \t partial train loss (single batch): 0.976370
# \t partial train loss (single batch): 0.977151
# \t partial train loss (single batch): 0.974668
# \t partial train loss (single batch): 0.977319
# \t partial train loss (single batch): 0.977146
# \t partial train loss (single batch): 0.975905
# \t partial train loss (single batch): 0.976788
# \t partial train loss (single batch): 0.975765
# \t partial train loss (single batch): 0.975285
# \t partial train loss (single batch): 0.979499
# \t partial train loss (single batch): 0.978941
# \t partial train loss (single batch): 0.977317
# \t partial train loss (single batch): 0.975156
# \t partial train loss (single batch): 0.974934
# \t partial train loss (single batch): 0.978817
# \t partial train loss (single batch): 0.971327
# \t partial train loss (single batch): 0.973695
# \t partial train loss (single batch): 0.973371
# \t partial train loss (single batch): 0.974644
# \t partial train loss (single batch): 0.972815
# \t partial train loss (single batch): 0.975970
# \t partial train loss (single batch): 0.972687
# \t partial train loss (single batch): 0.978726
# \t partial train loss (single batch): 0.974152
# \t partial train loss (single batch): 0.975314
# \t partial train loss (single batch): 0.973518
# \t partial train loss (single batch): 0.976396
# \t partial train loss (single batch): 0.977896
# \t partial train loss (single batch): 0.973149
# \t partial train loss (single batch): 0.969927
# \t partial train loss (single batch): 0.976252
# \t partial train loss (single batch): 0.971820
# \t partial train loss (single batch): 0.973396
# \t partial train loss (single batch): 0.967896
# \t partial train loss (single batch): 0.972059
# \t partial train loss (single batch): 0.974245
# \t partial train loss (single batch): 0.970537
# \t partial train loss (single batch): 0.970520
# \t partial train loss (single batch): 0.973070
# \t partial train loss (single batch): 0.971729
# \t partial train loss (single batch): 0.972276
# \t partial train loss (single batch): 0.971938
# \t partial train loss (single batch): 0.972119
# \t partial train loss (single batch): 0.971606
# \t partial train loss (single batch): 0.969331
# \t partial train loss (single batch): 0.966689
# \t partial train loss (single batch): 0.967391
# \t partial train loss (single batch): 0.969736
# \t partial train loss (single batch): 0.970861
# \t partial train loss (single batch): 0.971127
# \t partial train loss (single batch): 0.968442
# \t partial train loss (single batch): 0.969213
# \t partial train loss (single batch): 0.969575
# \t partial train loss (single batch): 0.970050
# \t partial train loss (single batch): 0.972066
# \t partial train loss (single batch): 0.967296
# \t partial train loss (single batch): 0.967932
# \t partial train loss (single batch): 0.973757
# \t partial train loss (single batch): 0.973776
# \t partial train loss (single batch): 0.967247
# \t partial train loss (single batch): 0.965855
# \t partial train loss (single batch): 0.962757
# \t partial train loss (single batch): 0.966854
# \t partial train loss (single batch): 0.970616
# \t partial train loss (single batch): 0.968718
# \t partial train loss (single batch): 0.969014
# \t partial train loss (single batch): 0.968662
# \t partial train loss (single batch): 0.964618
# \t partial train loss (single batch): 0.966377
# \t partial train loss (single batch): 0.963905
# \t partial train loss (single batch): 0.968246
# \t partial train loss (single batch): 0.964778
# \t partial train loss (single batch): 0.961383
# \t partial train loss (single batch): 0.964158
# \t partial train loss (single batch): 0.968384
# \t partial train loss (single batch): 0.966184
# \t partial train loss (single batch): 0.965243
# \t partial train loss (single batch): 0.964702
# \t partial train loss (single batch): 0.969224
# \t partial train loss (single batch): 0.962286
# \t partial train loss (single batch): 0.963000
# \t partial train loss (single batch): 0.966436
# \t partial train loss (single batch): 0.963231
# \t partial train loss (single batch): 0.964843
# \t partial train loss (single batch): 0.966111
# \t partial train loss (single batch): 0.968367
# \t partial train loss (single batch): 0.961781
# \t partial train loss (single batch): 0.963954
# \t partial train loss (single batch): 0.962982
# \t partial train loss (single batch): 0.961619
# \t partial train loss (single batch): 0.962242
# \t partial train loss (single batch): 0.962468
# \t partial train loss (single batch): 0.965471
# \t partial train loss (single batch): 0.966056
# \t partial train loss (single batch): 0.967057
# \t partial train loss (single batch): 0.965175
# \t partial train loss (single batch): 0.964007
# \t partial train loss (single batch): 0.960367
# \t partial train loss (single batch): 0.964507
# \t partial train loss (single batch): 0.960145
# \t partial train loss (single batch): 0.961808
# \t partial train loss (single batch): 0.966109
# \t partial train loss (single batch): 0.961712
# \t partial train loss (single batch): 0.964008
# \t partial train loss (single batch): 0.960130
# \t partial train loss (single batch): 0.963878
# \t partial train loss (single batch): 0.963271
# \t partial train loss (single batch): 0.962314
# \t partial train loss (single batch): 0.961267
# \t partial train loss (single batch): 0.962405
# \t partial train loss (single batch): 0.966712
# \t partial train loss (single batch): 0.964211
# \t partial train loss (single batch): 0.961384
# \t partial train loss (single batch): 0.962238
# \t partial train loss (single batch): 0.962990
# \t partial train loss (single batch): 0.962739
# \t partial train loss (single batch): 0.963361
# \t partial train loss (single batch): 0.962583
# \t partial train loss (single batch): 0.958685
# \t partial train loss (single batch): 0.965108
# \t partial train loss (single batch): 0.961855
# \t partial train loss (single batch): 0.960327
# \t partial train loss (single batch): 0.958240
# \t partial train loss (single batch): 0.965300
# \t partial train loss (single batch): 0.957387
# \t partial train loss (single batch): 0.959158
# \t partial train loss (single batch): 0.961665
# \t partial train loss (single batch): 0.960597
# \t partial train loss (single batch): 0.960811
# \t partial train loss (single batch): 0.956653
# \t partial train loss (single batch): 0.958685
# \t partial train loss (single batch): 0.959540
# \t partial train loss (single batch): 0.961767
# \t partial train loss (single batch): 0.956696
# \t partial train loss (single batch): 0.958748
# \t partial train loss (single batch): 0.959579
# \t partial train loss (single batch): 0.961300
# \t partial train loss (single batch): 0.961536
# \t partial train loss (single batch): 0.961167
# \t partial train loss (single batch): 0.958734
# \t partial train loss (single batch): 0.956939
# \t partial train loss (single batch): 0.961112
# \t partial train loss (single batch): 0.957930
# \t partial train loss (single batch): 0.958140
# \t partial train loss (single batch): 0.958373
# \t partial train loss (single batch): 0.958500
# \t partial train loss (single batch): 0.962704
# \t partial train loss (single batch): 0.959007
# \t partial train loss (single batch): 0.957177
# \t partial train loss (single batch): 0.956281
# \t partial train loss (single batch): 0.958350
# \t partial train loss (single batch): 0.955430
# \n EPOCH 3/20 \t train loss 0.970 \t val loss 0.959
# \t partial train loss (single batch): 0.958826
# \t partial train loss (single batch): 0.960841
# \t partial train loss (single batch): 0.959341
# \t partial train loss (single batch): 0.959887
# \t partial train loss (single batch): 0.956861
# \t partial train loss (single batch): 0.955600
# \t partial train loss (single batch): 0.958569
# \t partial train loss (single batch): 0.958853
# \t partial train loss (single batch): 0.958420
# \t partial train loss (single batch): 0.957877
# \t partial train loss (single batch): 0.954400
# \t partial train loss (single batch): 0.956380
# \t partial train loss (single batch): 0.957687
# \t partial train loss (single batch): 0.959877
# \t partial train loss (single batch): 0.960956
# \t partial train loss (single batch): 0.960684
# \t partial train loss (single batch): 0.956469
# \t partial train loss (single batch): 0.958884
# \t partial train loss (single batch): 0.957545
# \t partial train loss (single batch): 0.953235
# \t partial train loss (single batch): 0.954826
# \t partial train loss (single batch): 0.957059
# \t partial train loss (single batch): 0.956807
# \t partial train loss (single batch): 0.955525
# \t partial train loss (single batch): 0.958040
# \t partial train loss (single batch): 0.957391
# \t partial train loss (single batch): 0.957173
# \t partial train loss (single batch): 0.958309
# \t partial train loss (single batch): 0.957137
# \t partial train loss (single batch): 0.956528
# \t partial train loss (single batch): 0.953904
# \t partial train loss (single batch): 0.955485
# \t partial train loss (single batch): 0.959468
# \t partial train loss (single batch): 0.955257
# \t partial train loss (single batch): 0.955162
# \t partial train loss (single batch): 0.953978
# \t partial train loss (single batch): 0.954514
# \t partial train loss (single batch): 0.957561
# \t partial train loss (single batch): 0.952446
# \t partial train loss (single batch): 0.955626
# \t partial train loss (single batch): 0.953565
# \t partial train loss (single batch): 0.954056
# \t partial train loss (single batch): 0.956118
# \t partial train loss (single batch): 0.953587
# \t partial train loss (single batch): 0.955381
# \t partial train loss (single batch): 0.959957
# \t partial train loss (single batch): 0.958618
# \t partial train loss (single batch): 0.956587
# \t partial train loss (single batch): 0.956133
# \t partial train loss (single batch): 0.955447
# \t partial train loss (single batch): 0.956503
# \t partial train loss (single batch): 0.949911
# \t partial train loss (single batch): 0.953814
# \t partial train loss (single batch): 0.953004
# \t partial train loss (single batch): 0.955748
# \t partial train loss (single batch): 0.952842
# \t partial train loss (single batch): 0.957004
# \t partial train loss (single batch): 0.953556
# \t partial train loss (single batch): 0.957629
# \t partial train loss (single batch): 0.956046
# \t partial train loss (single batch): 0.953889
# \t partial train loss (single batch): 0.956255
# \t partial train loss (single batch): 0.955661
# \t partial train loss (single batch): 0.957193
# \t partial train loss (single batch): 0.953078
# \t partial train loss (single batch): 0.950188
# \t partial train loss (single batch): 0.956728
# \t partial train loss (single batch): 0.954925
# \t partial train loss (single batch): 0.953215
# \t partial train loss (single batch): 0.952683
# \t partial train loss (single batch): 0.954201
# \t partial train loss (single batch): 0.953188
# \t partial train loss (single batch): 0.952027
# \t partial train loss (single batch): 0.953070
# \t partial train loss (single batch): 0.954949
# \t partial train loss (single batch): 0.955522
# \t partial train loss (single batch): 0.954491
# \t partial train loss (single batch): 0.954297
# \t partial train loss (single batch): 0.954263
# \t partial train loss (single batch): 0.951072
# \t partial train loss (single batch): 0.951186
# \t partial train loss (single batch): 0.949197
# \t partial train loss (single batch): 0.950879
# \t partial train loss (single batch): 0.952632
# \t partial train loss (single batch): 0.953016
# \t partial train loss (single batch): 0.952457
# \t partial train loss (single batch): 0.952597
# \t partial train loss (single batch): 0.952261
# \t partial train loss (single batch): 0.953420
# \t partial train loss (single batch): 0.953556
# \t partial train loss (single batch): 0.953601
# \t partial train loss (single batch): 0.950776
# \t partial train loss (single batch): 0.952525
# \t partial train loss (single batch): 0.955111
# \t partial train loss (single batch): 0.956443
# \t partial train loss (single batch): 0.952369
# \t partial train loss (single batch): 0.951288
# \t partial train loss (single batch): 0.948554
# \t partial train loss (single batch): 0.951117
# \t partial train loss (single batch): 0.954876
# \t partial train loss (single batch): 0.953284
# \t partial train loss (single batch): 0.954778
# \t partial train loss (single batch): 0.954539
# \t partial train loss (single batch): 0.949991
# \t partial train loss (single batch): 0.952163
# \t partial train loss (single batch): 0.950585
# \t partial train loss (single batch): 0.952405
# \t partial train loss (single batch): 0.952574
# \t partial train loss (single batch): 0.947633
# \t partial train loss (single batch): 0.949497
# \t partial train loss (single batch): 0.952081
# \t partial train loss (single batch): 0.949226
# \t partial train loss (single batch): 0.950771
# \t partial train loss (single batch): 0.951868
# \t partial train loss (single batch): 0.954570
# \t partial train loss (single batch): 0.947429
# \t partial train loss (single batch): 0.949420
# \t partial train loss (single batch): 0.953211
# \t partial train loss (single batch): 0.950610
# \t partial train loss (single batch): 0.952285
# \t partial train loss (single batch): 0.952690
# \t partial train loss (single batch): 0.955096
# \t partial train loss (single batch): 0.947405
# \t partial train loss (single batch): 0.951290
# \t partial train loss (single batch): 0.948796
# \t partial train loss (single batch): 0.950281
# \t partial train loss (single batch): 0.949190
# \t partial train loss (single batch): 0.950610
# \t partial train loss (single batch): 0.952480
# \t partial train loss (single batch): 0.952628
# \t partial train loss (single batch): 0.956306
# \t partial train loss (single batch): 0.952995
# \t partial train loss (single batch): 0.950610
# \t partial train loss (single batch): 0.949490
# \t partial train loss (single batch): 0.952892
# \t partial train loss (single batch): 0.949334
# \t partial train loss (single batch): 0.948222
# \t partial train loss (single batch): 0.952808
# \t partial train loss (single batch): 0.948880
# \t partial train loss (single batch): 0.949600
# \t partial train loss (single batch): 0.948837
# \t partial train loss (single batch): 0.950373
# \t partial train loss (single batch): 0.951592
# \t partial train loss (single batch): 0.950223
# \t partial train loss (single batch): 0.949054
# \t partial train loss (single batch): 0.950590
# \t partial train loss (single batch): 0.954436
# \t partial train loss (single batch): 0.952557
# \t partial train loss (single batch): 0.949737
# \t partial train loss (single batch): 0.949004
# \t partial train loss (single batch): 0.951972
# \t partial train loss (single batch): 0.951511
# \t partial train loss (single batch): 0.949401
# \t partial train loss (single batch): 0.951561
# \t partial train loss (single batch): 0.949997
# \t partial train loss (single batch): 0.954508
# \t partial train loss (single batch): 0.949810
# \t partial train loss (single batch): 0.947705
# \t partial train loss (single batch): 0.946240
# \t partial train loss (single batch): 0.951759
# \t partial train loss (single batch): 0.946673
# \t partial train loss (single batch): 0.948682
# \t partial train loss (single batch): 0.952875
# \t partial train loss (single batch): 0.949149
# \t partial train loss (single batch): 0.948885
# \t partial train loss (single batch): 0.948466
# \t partial train loss (single batch): 0.949820
# \t partial train loss (single batch): 0.948032
# \t partial train loss (single batch): 0.951097
# \t partial train loss (single batch): 0.944068
# \t partial train loss (single batch): 0.949703
# \t partial train loss (single batch): 0.950259
# \t partial train loss (single batch): 0.950642
# \t partial train loss (single batch): 0.951425
# \t partial train loss (single batch): 0.948488
# \t partial train loss (single batch): 0.949372
# \t partial train loss (single batch): 0.948954
# \t partial train loss (single batch): 0.951262
# \t partial train loss (single batch): 0.947861
# \t partial train loss (single batch): 0.948424
# \t partial train loss (single batch): 0.949481
# \t partial train loss (single batch): 0.947136
# \t partial train loss (single batch): 0.952763
# \t partial train loss (single batch): 0.949215
# \t partial train loss (single batch): 0.946242
# \t partial train loss (single batch): 0.946719
# \t partial train loss (single batch): 0.947843
# \t partial train loss (single batch): 0.947289
# \n EPOCH 4/20 \t train loss 0.953 \t val loss 0.949
# \t partial train loss (single batch): 0.949510
# \t partial train loss (single batch): 0.951029
# \t partial train loss (single batch): 0.948967
# \t partial train loss (single batch): 0.950239
# \t partial train loss (single batch): 0.944365
# \t partial train loss (single batch): 0.946542
# \t partial train loss (single batch): 0.948054
# \t partial train loss (single batch): 0.947493
# \t partial train loss (single batch): 0.948761
# \t partial train loss (single batch): 0.948109
# \t partial train loss (single batch): 0.946648
# \t partial train loss (single batch): 0.949309
# \t partial train loss (single batch): 0.948627
# \t partial train loss (single batch): 0.948173
# \t partial train loss (single batch): 0.952302
# \t partial train loss (single batch): 0.951412
# \t partial train loss (single batch): 0.944504
# \t partial train loss (single batch): 0.948971
# \t partial train loss (single batch): 0.947635
# \t partial train loss (single batch): 0.944881
# \t partial train loss (single batch): 0.945591
# \t partial train loss (single batch): 0.948090
# \t partial train loss (single batch): 0.948687
# \t partial train loss (single batch): 0.946551
# \t partial train loss (single batch): 0.946386
# \t partial train loss (single batch): 0.945222
# \t partial train loss (single batch): 0.948952
# \t partial train loss (single batch): 0.947819
# \t partial train loss (single batch): 0.948249
# \t partial train loss (single batch): 0.947861
# \t partial train loss (single batch): 0.946093
# \t partial train loss (single batch): 0.947611
# \t partial train loss (single batch): 0.949020
# \t partial train loss (single batch): 0.947392
# \t partial train loss (single batch): 0.947276
# \t partial train loss (single batch): 0.944907
# \t partial train loss (single batch): 0.948582
# \t partial train loss (single batch): 0.949524
# \t partial train loss (single batch): 0.945865
# \t partial train loss (single batch): 0.947592
# \t partial train loss (single batch): 0.947961
# \t partial train loss (single batch): 0.946367
# \t partial train loss (single batch): 0.946941
# \t partial train loss (single batch): 0.947934
# \t partial train loss (single batch): 0.948196
# \t partial train loss (single batch): 0.951562
# \t partial train loss (single batch): 0.949091
# \t partial train loss (single batch): 0.948775
# \t partial train loss (single batch): 0.947477
# \t partial train loss (single batch): 0.946059
# \t partial train loss (single batch): 0.949233
# \t partial train loss (single batch): 0.941840
# \t partial train loss (single batch): 0.945614
# \t partial train loss (single batch): 0.946043
# \t partial train loss (single batch): 0.947100
# \t partial train loss (single batch): 0.942397
# \t partial train loss (single batch): 0.949664
# \t partial train loss (single batch): 0.948166
# \t partial train loss (single batch): 0.947999
# \t partial train loss (single batch): 0.947235
# \t partial train loss (single batch): 0.945805
# \t partial train loss (single batch): 0.947935
# \t partial train loss (single batch): 0.946679
# \t partial train loss (single batch): 0.947597
# \t partial train loss (single batch): 0.945039
# \t partial train loss (single batch): 0.943263
# \t partial train loss (single batch): 0.950423
# \t partial train loss (single batch): 0.945835
# \t partial train loss (single batch): 0.948352
# \t partial train loss (single batch): 0.945149
# \t partial train loss (single batch): 0.946178
# \t partial train loss (single batch): 0.947892
# \t partial train loss (single batch): 0.944699
# \t partial train loss (single batch): 0.946178
# \t partial train loss (single batch): 0.946437
# \t partial train loss (single batch): 0.947451
# \t partial train loss (single batch): 0.948203
# \t partial train loss (single batch): 0.946838
# \t partial train loss (single batch): 0.946597
# \t partial train loss (single batch): 0.946347
# \t partial train loss (single batch): 0.945793
# \t partial train loss (single batch): 0.943229
# \t partial train loss (single batch): 0.941932
# \t partial train loss (single batch): 0.945381
# \t partial train loss (single batch): 0.946004
# \t partial train loss (single batch): 0.944646
# \t partial train loss (single batch): 0.946161
# \t partial train loss (single batch): 0.943175
# \t partial train loss (single batch): 0.945714
# \t partial train loss (single batch): 0.944620
# \t partial train loss (single batch): 0.947140
# \t partial train loss (single batch): 0.944082
# \t partial train loss (single batch): 0.945608
# \t partial train loss (single batch): 0.948334
# \t partial train loss (single batch): 0.948620
# \t partial train loss (single batch): 0.944479
# \t partial train loss (single batch): 0.942687
# \t partial train loss (single batch): 0.940517
# \t partial train loss (single batch): 0.942631
# \t partial train loss (single batch): 0.947287
# \t partial train loss (single batch): 0.946656
# \t partial train loss (single batch): 0.948823
# \t partial train loss (single batch): 0.946533
# \t partial train loss (single batch): 0.944938
# \t partial train loss (single batch): 0.942773
# \t partial train loss (single batch): 0.943358
# \t partial train loss (single batch): 0.944578
# \t partial train loss (single batch): 0.944575
# \t partial train loss (single batch): 0.941339
# \t partial train loss (single batch): 0.943900
# \t partial train loss (single batch): 0.946172
# \t partial train loss (single batch): 0.945662
# \t partial train loss (single batch): 0.943984
# \t partial train loss (single batch): 0.943021
# \t partial train loss (single batch): 0.947474
# \t partial train loss (single batch): 0.944009
# \t partial train loss (single batch): 0.942997
# \t partial train loss (single batch): 0.945101
# \t partial train loss (single batch): 0.943939
# \t partial train loss (single batch): 0.945190
# \t partial train loss (single batch): 0.946890
# \t partial train loss (single batch): 0.949621
# \t partial train loss (single batch): 0.941482
# \t partial train loss (single batch): 0.943616
# \t partial train loss (single batch): 0.943641
# \t partial train loss (single batch): 0.944064
# \t partial train loss (single batch): 0.943543
# \t partial train loss (single batch): 0.946544
# \t partial train loss (single batch): 0.947398
# \t partial train loss (single batch): 0.947233
# \t partial train loss (single batch): 0.948327
# \t partial train loss (single batch): 0.946536
# \t partial train loss (single batch): 0.944897
# \t partial train loss (single batch): 0.943391
# \t partial train loss (single batch): 0.945713
# \t partial train loss (single batch): 0.942005
# \t partial train loss (single batch): 0.943897
# \t partial train loss (single batch): 0.948335
# \t partial train loss (single batch): 0.942943
# \t partial train loss (single batch): 0.945854
# \t partial train loss (single batch): 0.940953
# \t partial train loss (single batch): 0.944849
# \t partial train loss (single batch): 0.945156
# \t partial train loss (single batch): 0.943849
# \t partial train loss (single batch): 0.943852
# \t partial train loss (single batch): 0.943937
# \t partial train loss (single batch): 0.947960
# \t partial train loss (single batch): 0.945410
# \t partial train loss (single batch): 0.943848
# \t partial train loss (single batch): 0.944466
# \t partial train loss (single batch): 0.943977
# \t partial train loss (single batch): 0.947064
# \t partial train loss (single batch): 0.946102
# \t partial train loss (single batch): 0.944430
# \t partial train loss (single batch): 0.942637
# \t partial train loss (single batch): 0.949266
# \t partial train loss (single batch): 0.945334
# \t partial train loss (single batch): 0.941500
# \t partial train loss (single batch): 0.941127
# \t partial train loss (single batch): 0.946050
# \t partial train loss (single batch): 0.940866
# \t partial train loss (single batch): 0.942605
# \t partial train loss (single batch): 0.946898
# \t partial train loss (single batch): 0.942906
# \t partial train loss (single batch): 0.944389
# \t partial train loss (single batch): 0.943959
# \t partial train loss (single batch): 0.944494
# \t partial train loss (single batch): 0.943355
# \t partial train loss (single batch): 0.946205
# \t partial train loss (single batch): 0.939536
# \t partial train loss (single batch): 0.944283
# \t partial train loss (single batch): 0.945266
# \t partial train loss (single batch): 0.945719
# \t partial train loss (single batch): 0.947142
# \t partial train loss (single batch): 0.942440
# \t partial train loss (single batch): 0.944453
# \t partial train loss (single batch): 0.944076
# \t partial train loss (single batch): 0.947352
# \t partial train loss (single batch): 0.941961
# \t partial train loss (single batch): 0.943154
# \t partial train loss (single batch): 0.943693
# \t partial train loss (single batch): 0.942199
# \t partial train loss (single batch): 0.949135
# \t partial train loss (single batch): 0.943897
# \t partial train loss (single batch): 0.941324
# \t partial train loss (single batch): 0.941759
# \t partial train loss (single batch): 0.942625
# \t partial train loss (single batch): 0.942809
# \n EPOCH 5/20 \t train loss 0.946 \t val loss 0.943
# \t partial train loss (single batch): 0.943460
# \t partial train loss (single batch): 0.945298
# \t partial train loss (single batch): 0.944246
# \t partial train loss (single batch): 0.945352
# \t partial train loss (single batch): 0.940062
# \t partial train loss (single batch): 0.942589
# \t partial train loss (single batch): 0.944470
# \t partial train loss (single batch): 0.942299
# \t partial train loss (single batch): 0.945135
# \t partial train loss (single batch): 0.941855
# \t partial train loss (single batch): 0.940821
# \t partial train loss (single batch): 0.941601
# \t partial train loss (single batch): 0.940366
# \t partial train loss (single batch): 0.944957
# \t partial train loss (single batch): 0.947454
# \t partial train loss (single batch): 0.947283
# \t partial train loss (single batch): 0.941647
# \t partial train loss (single batch): 0.944058
# \t partial train loss (single batch): 0.941599
# \t partial train loss (single batch): 0.941444
# \t partial train loss (single batch): 0.941025
# \t partial train loss (single batch): 0.945150
# \t partial train loss (single batch): 0.942499
# \t partial train loss (single batch): 0.941431
# \t partial train loss (single batch): 0.942618
# \t partial train loss (single batch): 0.942400
# \t partial train loss (single batch): 0.943756
# \t partial train loss (single batch): 0.943984
# \t partial train loss (single batch): 0.943059
# \t partial train loss (single batch): 0.942164
# \t partial train loss (single batch): 0.940389
# \t partial train loss (single batch): 0.941121
# \t partial train loss (single batch): 0.944875
# \t partial train loss (single batch): 0.942558
# \t partial train loss (single batch): 0.940699
# \t partial train loss (single batch): 0.939795
# \t partial train loss (single batch): 0.941164
# \t partial train loss (single batch): 0.944010
# \t partial train loss (single batch): 0.939062
# \t partial train loss (single batch): 0.943063
# \t partial train loss (single batch): 0.941106
# \t partial train loss (single batch): 0.942579
# \t partial train loss (single batch): 0.941678
# \t partial train loss (single batch): 0.941277
# \t partial train loss (single batch): 0.943751
# \t partial train loss (single batch): 0.946746
# \t partial train loss (single batch): 0.944863
# \t partial train loss (single batch): 0.944691
# \t partial train loss (single batch): 0.941949
# \t partial train loss (single batch): 0.942422
# \t partial train loss (single batch): 0.943317
# \t partial train loss (single batch): 0.938386
# \t partial train loss (single batch): 0.940822
# \t partial train loss (single batch): 0.940885
# \t partial train loss (single batch): 0.942432
# \t partial train loss (single batch): 0.940581
# \t partial train loss (single batch): 0.944081
# \t partial train loss (single batch): 0.943594
# \t partial train loss (single batch): 0.945197
# \t partial train loss (single batch): 0.942713
# \t partial train loss (single batch): 0.941191
# \t partial train loss (single batch): 0.944269
# \t partial train loss (single batch): 0.942494
# \t partial train loss (single batch): 0.943832
# \t partial train loss (single batch): 0.942783
# \t partial train loss (single batch): 0.939469
# \t partial train loss (single batch): 0.944342
# \t partial train loss (single batch): 0.941371
# \t partial train loss (single batch): 0.942316
# \t partial train loss (single batch): 0.938327
# \t partial train loss (single batch): 0.942642
# \t partial train loss (single batch): 0.943483
# \t partial train loss (single batch): 0.939491
# \t partial train loss (single batch): 0.940829
# \t partial train loss (single batch): 0.942321
# ...
# \t partial train loss (single batch): 0.921979
# \t partial train loss (single batch): 0.927127
# \t partial train loss (single batch): 0.923228
# \t partial train loss (single batch): 0.921534
# \t partial train loss (single batch): 0.921844
# \t partial train loss (single batch): 0.923401
# \t partial train loss (single batch): 0.922890
# \t partial train loss (single batch): 0.927941
# \t partial train loss (single batch): 0.924468
# \t partial train loss (single batch): 0.925221
# \t partial train loss (single batch): 0.923954
# \t partial train loss (single batch): 0.923403
# \t partial train loss (single batch): 0.925451
# \t partial train loss (single batch): 0.919894
# \t partial train loss (single batch): 0.923029
# \t partial train loss (single batch): 0.922022
# \t partial train loss (single batch): 0.922848
# \t partial train loss (single batch): 0.921249
# \t partial train loss (single batch): 0.927496
# \t partial train loss (single batch): 0.925487
# \t partial train loss (single batch): 0.926603
# \t partial train loss (single batch): 0.925776
# \t partial train loss (single batch): 0.922577
# \t partial train loss (single batch): 0.927411
# \t partial train loss (single batch): 0.925687
# \t partial train loss (single batch): 0.926317
# \t partial train loss (single batch): 0.924653
# \t partial train loss (single batch): 0.922117
# \t partial train loss (single batch): 0.927567
# \t partial train loss (single batch): 0.923338
# \t partial train loss (single batch): 0.924018
# \t partial train loss (single batch): 0.921511
# \t partial train loss (single batch): 0.923830
# \t partial train loss (single batch): 0.923918
# \t partial train loss (single batch): 0.922136
# \t partial train loss (single batch): 0.923888
# \t partial train loss (single batch): 0.923500
# \t partial train loss (single batch): 0.927126
# \t partial train loss (single batch): 0.926551
# \t partial train loss (single batch): 0.925044
# \t partial train loss (single batch): 0.924589
# \t partial train loss (single batch): 0.922449
# \t partial train loss (single batch): 0.924722
# \t partial train loss (single batch): 0.920773
# \t partial train loss (single batch): 0.921193
# \t partial train loss (single batch): 0.920954
# \t partial train loss (single batch): 0.924078
# \t partial train loss (single batch): 0.922769
# \t partial train loss (single batch): 0.925092
# \t partial train loss (single batch): 0.923385
# \t partial train loss (single batch): 0.922901
# \t partial train loss (single batch): 0.922574
# \t partial train loss (single batch): 0.925848
# \t partial train loss (single batch): 0.920372
# \t partial train loss (single batch): 0.924695
# \t partial train loss (single batch): 0.927200
# \t partial train loss (single batch): 0.926713
# \t partial train loss (single batch): 0.922959
# \t partial train loss (single batch): 0.920574
# \t partial train loss (single batch): 0.918213
# \t partial train loss (single batch): 0.922196
# \t partial train loss (single batch): 0.923891
# \t partial train loss (single batch): 0.925719
# \t partial train loss (single batch): 0.925923
# \t partial train loss (single batch): 0.926793
# \t partial train loss (single batch): 0.921751
# \t partial train loss (single batch): 0.923361
# \t partial train loss (single batch): 0.919931
# \t partial train loss (single batch): 0.921088
# \t partial train loss (single batch): 0.923262
# \t partial train loss (single batch): 0.917220
# \t partial train loss (single batch): 0.920573
# \t partial train loss (single batch): 0.925798
# \t partial train loss (single batch): 0.924025
# \t partial train loss (single batch): 0.923892
# \t partial train loss (single batch): 0.921309
# \t partial train loss (single batch): 0.927840
# \t partial train loss (single batch): 0.920371
# \t partial train loss (single batch): 0.922416
# \t partial train loss (single batch): 0.927159
# \t partial train loss (single batch): 0.922109
# \t partial train loss (single batch): 0.922664
# \t partial train loss (single batch): 0.925200
# \t partial train loss (single batch): 0.928562
# \t partial train loss (single batch): 0.917612
# \t partial train loss (single batch): 0.924247
# \t partial train loss (single batch): 0.922512
# \t partial train loss (single batch): 0.921941
# \t partial train loss (single batch): 0.922820
# \t partial train loss (single batch): 0.923728
# \t partial train loss (single batch): 0.929206
# \t partial train loss (single batch): 0.924806
# \t partial train loss (single batch): 0.928967
# \t partial train loss (single batch): 0.925430
# \t partial train loss (single batch): 0.924501
# \t partial train loss (single batch): 0.920188
# \t partial train loss (single batch): 0.925689
# \t partial train loss (single batch): 0.922340
# \t partial train loss (single batch): 0.920871
# \t partial train loss (single batch): 0.927877
# \t partial train loss (single batch): 0.924575
# \t partial train loss (single batch): 0.922336
# \t partial train loss (single batch): 0.919971
# \t partial train loss (single batch): 0.923083
# \t partial train loss (single batch): 0.924344
# \t partial train loss (single batch): 0.923767
# \t partial train loss (single batch): 0.922864
# \t partial train loss (single batch): 0.924871
# \t partial train loss (single batch): 0.927451
# \t partial train loss (single batch): 0.922914
# \t partial train loss (single batch): 0.922605
# \t partial train loss (single batch): 0.924620
# \t partial train loss (single batch): 0.922835
# \t partial train loss (single batch): 0.926676
# \t partial train loss (single batch): 0.923856
# \t partial train loss (single batch): 0.926484
# \t partial train loss (single batch): 0.922669
# \t partial train loss (single batch): 0.928986
# \t partial train loss (single batch): 0.923595
# \t partial train loss (single batch): 0.919307
# \t partial train loss (single batch): 0.920960
# \t partial train loss (single batch): 0.928970
# \t partial train loss (single batch): 0.916694
# \t partial train loss (single batch): 0.923493
# \t partial train loss (single batch): 0.925412
# \t partial train loss (single batch): 0.923389
# \t partial train loss (single batch): 0.923339
# \t partial train loss (single batch): 0.920626
# \t partial train loss (single batch): 0.925226
# \t partial train loss (single batch): 0.922621
# \t partial train loss (single batch): 0.925613
# \t partial train loss (single batch): 0.919001
# \t partial train loss (single batch): 0.923188
# \t partial train loss (single batch): 0.925357
# \t partial train loss (single batch): 0.925003
# \t partial train loss (single batch): 0.926535
# \t partial train loss (single batch): 0.923906
# \t partial train loss (single batch): 0.923503
# \t partial train loss (single batch): 0.924820
# \t partial train loss (single batch): 0.926236
# \t partial train loss (single batch): 0.921205
# \t partial train loss (single batch): 0.920556
# \t partial train loss (single batch): 0.922603
# \t partial train loss (single batch): 0.921347
# \t partial train loss (single batch): 0.926902
# \t partial train loss (single batch): 0.923680
# \t partial train loss (single batch): 0.921899
# \t partial train loss (single batch): 0.920422
# \t partial train loss (single batch): 0.921337
# \t partial train loss (single batch): 0.919925
# \n EPOCH 19/20 \t train loss 0.924 \t val loss 0.924
# \t partial train loss (single batch): 0.924507
# \t partial train loss (single batch): 0.925787
# \t partial train loss (single batch): 0.925384
# \t partial train loss (single batch): 0.925408
# \t partial train loss (single batch): 0.921727
# \t partial train loss (single batch): 0.921974
# \t partial train loss (single batch): 0.923518
# \t partial train loss (single batch): 0.923415
# \t partial train loss (single batch): 0.923424
# \t partial train loss (single batch): 0.923036
# \t partial train loss (single batch): 0.921507
# \t partial train loss (single batch): 0.921711
# \t partial train loss (single batch): 0.921842
# \t partial train loss (single batch): 0.925839
# \t partial train loss (single batch): 0.926370
# \t partial train loss (single batch): 0.925728
# \t partial train loss (single batch): 0.921680
# \t partial train loss (single batch): 0.924701
# \t partial train loss (single batch): 0.921800
# \t partial train loss (single batch): 0.920335
# \t partial train loss (single batch): 0.921524
# \t partial train loss (single batch): 0.922675
# \t partial train loss (single batch): 0.922764
# \t partial train loss (single batch): 0.923525
# \t partial train loss (single batch): 0.924690
# \t partial train loss (single batch): 0.922304
# \t partial train loss (single batch): 0.925233
# \t partial train loss (single batch): 0.923913
# \t partial train loss (single batch): 0.923943
# \t partial train loss (single batch): 0.923684
# \t partial train loss (single batch): 0.920719
# \t partial train loss (single batch): 0.921442
# \t partial train loss (single batch): 0.926893
# \t partial train loss (single batch): 0.923744
# \t partial train loss (single batch): 0.920002
# \t partial train loss (single batch): 0.921443
# \t partial train loss (single batch): 0.923449
# \t partial train loss (single batch): 0.925812
# \t partial train loss (single batch): 0.920472
# \t partial train loss (single batch): 0.926534
# \t partial train loss (single batch): 0.921905
# \t partial train loss (single batch): 0.921140
# \t partial train loss (single batch): 0.920802
# \t partial train loss (single batch): 0.924276
# \t partial train loss (single batch): 0.922964
# \t partial train loss (single batch): 0.928877
# \t partial train loss (single batch): 0.926009
# \t partial train loss (single batch): 0.923215
# \t partial train loss (single batch): 0.923540
# \t partial train loss (single batch): 0.921557
# \t partial train loss (single batch): 0.924988
# \t partial train loss (single batch): 0.918377
# \t partial train loss (single batch): 0.920415
# \t partial train loss (single batch): 0.921914
# \t partial train loss (single batch): 0.921059
# \t partial train loss (single batch): 0.919516
# \t partial train loss (single batch): 0.928054
# \t partial train loss (single batch): 0.924735
# \t partial train loss (single batch): 0.928630
# \t partial train loss (single batch): 0.924473
# \t partial train loss (single batch): 0.921626
# \t partial train loss (single batch): 0.926744
# \t partial train loss (single batch): 0.924867
# \t partial train loss (single batch): 0.924526
# \t partial train loss (single batch): 0.923131
# \t partial train loss (single batch): 0.918916
# \t partial train loss (single batch): 0.926871
# \t partial train loss (single batch): 0.922531
# \t partial train loss (single batch): 0.922812
# \t partial train loss (single batch): 0.920189
# \t partial train loss (single batch): 0.922966
# \t partial train loss (single batch): 0.923892
# \t partial train loss (single batch): 0.921256
# \t partial train loss (single batch): 0.921660
# \t partial train loss (single batch): 0.922226
# \t partial train loss (single batch): 0.925285
# \t partial train loss (single batch): 0.924197
# \t partial train loss (single batch): 0.923803
# \t partial train loss (single batch): 0.921852
# \t partial train loss (single batch): 0.921577
# \t partial train loss (single batch): 0.922999
# \t partial train loss (single batch): 0.919730
# \t partial train loss (single batch): 0.919024
# \t partial train loss (single batch): 0.923869
# \t partial train loss (single batch): 0.923855
# \t partial train loss (single batch): 0.921098
# \t partial train loss (single batch): 0.922493
# \t partial train loss (single batch): 0.919967
# \t partial train loss (single batch): 0.922509
# \t partial train loss (single batch): 0.921817
# \t partial train loss (single batch): 0.923107
# \t partial train loss (single batch): 0.921597
# \t partial train loss (single batch): 0.922119
# \t partial train loss (single batch): 0.925477
# \t partial train loss (single batch): 0.926078
# \t partial train loss (single batch): 0.921791
# \t partial train loss (single batch): 0.919698
# \t partial train loss (single batch): 0.918517
# \t partial train loss (single batch): 0.922199
# \t partial train loss (single batch): 0.923492
# \t partial train loss (single batch): 0.922261
# \t partial train loss (single batch): 0.926434
# \t partial train loss (single batch): 0.925179
# \t partial train loss (single batch): 0.920380
# \t partial train loss (single batch): 0.922203
# \t partial train loss (single batch): 0.918604
# \t partial train loss (single batch): 0.921326
# \t partial train loss (single batch): 0.923866
# \t partial train loss (single batch): 0.916801
# \t partial train loss (single batch): 0.920754
# \t partial train loss (single batch): 0.924894
# \t partial train loss (single batch): 0.922801
# \t partial train loss (single batch): 0.924585
# \t partial train loss (single batch): 0.921332
# \t partial train loss (single batch): 0.927619
# \t partial train loss (single batch): 0.920647
# \t partial train loss (single batch): 0.923313
# \t partial train loss (single batch): 0.925493
# \t partial train loss (single batch): 0.919577
# \t partial train loss (single batch): 0.924258
# \t partial train loss (single batch): 0.923355
# \t partial train loss (single batch): 0.928395
# \t partial train loss (single batch): 0.915804
# \t partial train loss (single batch): 0.923065
# \t partial train loss (single batch): 0.922561
# \t partial train loss (single batch): 0.920216
# \t partial train loss (single batch): 0.921147
# \t partial train loss (single batch): 0.923272
# \t partial train loss (single batch): 0.926335
# \t partial train loss (single batch): 0.923630
# \t partial train loss (single batch): 0.928426
# \t partial train loss (single batch): 0.924277
# \t partial train loss (single batch): 0.923992
# \t partial train loss (single batch): 0.919265
# \t partial train loss (single batch): 0.926362
# \t partial train loss (single batch): 0.921260
# \t partial train loss (single batch): 0.920786
# \t partial train loss (single batch): 0.927315
# \t partial train loss (single batch): 0.922763
# \t partial train loss (single batch): 0.921131
# \t partial train loss (single batch): 0.919244
# \t partial train loss (single batch): 0.923115
# \t partial train loss (single batch): 0.921314
# \t partial train loss (single batch): 0.923278
# \t partial train loss (single batch): 0.922028
# \t partial train loss (single batch): 0.925502
# \t partial train loss (single batch): 0.926701
# \t partial train loss (single batch): 0.923530
# \t partial train loss (single batch): 0.922341
# \t partial train loss (single batch): 0.924154
# \t partial train loss (single batch): 0.922541
# \t partial train loss (single batch): 0.926183
# \t partial train loss (single batch): 0.924345
# \t partial train loss (single batch): 0.924027
# \t partial train loss (single batch): 0.921516
# \t partial train loss (single batch): 0.928104
# \t partial train loss (single batch): 0.923800
# \t partial train loss (single batch): 0.920514
# \t partial train loss (single batch): 0.920890
# \t partial train loss (single batch): 0.925036
# \t partial train loss (single batch): 0.917317
# \t partial train loss (single batch): 0.919972
# \t partial train loss (single batch): 0.923826
# \t partial train loss (single batch): 0.922872
# \t partial train loss (single batch): 0.921661
# \t partial train loss (single batch): 0.921833
# \t partial train loss (single batch): 0.923395
# \t partial train loss (single batch): 0.924247
# \t partial train loss (single batch): 0.924002
# \t partial train loss (single batch): 0.919376
# \t partial train loss (single batch): 0.921426
# \t partial train loss (single batch): 0.921715
# \t partial train loss (single batch): 0.925073
# \t partial train loss (single batch): 0.925460
# \t partial train loss (single batch): 0.922484
# \t partial train loss (single batch): 0.921477
# \t partial train loss (single batch): 0.923383
# \t partial train loss (single batch): 0.924882
# \t partial train loss (single batch): 0.922076
# \t partial train loss (single batch): 0.921173
# \t partial train loss (single batch): 0.921739
# \t partial train loss (single batch): 0.921808
# \t partial train loss (single batch): 0.926135
# \t partial train loss (single batch): 0.922974
# \t partial train loss (single batch): 0.919560
# \t partial train loss (single batch): 0.920461
# \t partial train loss (single batch): 0.922268
# \t partial train loss (single batch): 0.918210
# \n EPOCH 20/20 \t train loss 0.923 \t val loss 0.924

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.9220144748687744

# %%
# Train and validation loss

plt.figure(figsize=(7,5))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %%
'''
У ході виконання лабораторної роботи було реалізовано автокодувальну нейронну мережу
в середовищі PyTorch для задачі відновлення зображень рукописних цифр, спотворених шумом.
До вхідних даних штучно додавався гаусівський шум, що дозволило перевірити здатність
моделі виділяти ключові ознаки зображення навіть у складних умовах. Побудована мережа
складалася з енкодера та декодера, які забезпечували стискання та відновлення інформації
відповідно. Навчання здійснювалося з використанням функції втрат MSE, і результати показали
поступове зменшення помилки, що свідчить про успішне засвоєння моделі. Візуальне порівняння
оригінальних, зашумлених та відновлених зображень підтвердило ефективність автокодувальника
у фільтрації шуму та збереженні важливих деталей. Отримані результати демонструють практичну
цінність автокодувальних мереж у задачах попередньої обробки візуальних даних.
'''
