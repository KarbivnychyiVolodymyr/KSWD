# %% [markdown]
# <a href="https://colab.research.google.com/github/KarbivnychyiVolodymyr/KSWD/blob/main/Karbivnichy_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-21cf4e04-a6bd-4076-9410-db92e9a4ab86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21cf4e04-a6bd-4076-9410-db92e9a4ab86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs('/root/.kaggle', exist_ok=True)
os.rename('kaggle.json', '/root/.kaggle/kaggle.json')

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                                    title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# jayaantanaath/student-habits-vs-academic-performance                   Student Habits vs Academic Performance                   19512  2025-04-12 10:49:08.663000           8196        147  1.0
# shahriar26s/anemia-detection-dataset                                   Anemia Detection Dataset                                  2503  2025-04-26 05:34:18.807000            847         24  1.0
# adilshamim8/student-depression-dataset                                 Student Depression Dataset                              467020  2025-03-13 03:12:30.423000          23583        359  1.0
# ...

# %%
# !kaggle datasets download -d shlokraval/ppe-dataset-yolov8 -p /content/
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/shlokraval/ppe-dataset-yolov8
# License(s): apache-2.0

# %%
import zipfile
import os

# Шлях до архіву
zip_path = '/content/ppe-dataset-yolov8.zip'

# Шлях для розпакування
extract_path = '/content/ppe_dataset'

# Розпаковуємо архів
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Перевірка структури
print(os.listdir(extract_path))
# Out:
# ['README.dataset.txt', 'train', 'data.yaml', 'README.roboflow.txt', 'valid', 'test']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import yaml

data = {
    'train': '/content/dataset/train',
    'val': '/content/dataset/valid',
    'test': '/content/dataset/test',
    'nc': 10,  # Кількість класів
    'names': ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'Machinery', 'Vehicle']  # Класи
}

with open('/content/data.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
import yaml
import os

# Перевіримо існування каталогів
dataset_dir = '/content/dataset'  # ваш каталог розпакованого датасету

train_dir = os.path.join(dataset_dir, 'train')
valid_dir = os.path.join(dataset_dir, 'valid')
test_dir = os.path.join(dataset_dir, 'test')

# Перевірка на існування папок
print("Train dir exists:", os.path.exists(train_dir))
print("Valid dir exists:", os.path.exists(valid_dir))
print("Test dir exists:", os.path.exists(test_dir))

# Оновлений YAML конфігураційний файл
data = {
    'train': train_dir,
    'val': valid_dir,
    'test': test_dir,
    'nc': 10,  # Кількість класів
    'names': ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'Machinery', 'Vehicle']  # Класи
}

# Записуємо в новий файл
with open('/content/data.yaml', 'w') as f:
    yaml.dump(data, f)
# Out:
# Train dir exists: False
# Valid dir exists: False
# Test dir exists: False

# %%
# Виведення логів та метрик
import matplotlib.pyplot as plt

# Завантаження логів тренування
log = model.val()  # Для перевірки точності на валідаційних даних

# Виведення графіків точності та втрат
plt.plot(log['results']['metrics']['precision'], label='Precision')
plt.plot(log['results']['metrics']['recall'], label='Recall')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.legend()
plt.title('Precision and Recall')
plt.show()
# Out:
# Ultralytics 8.3.120 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)

# %%
# Виведення кривих навчання
history = model.history  # Історія навчання
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Виведення кривих точності
axs[0].plot(history['epoch'], history['metrics']['precision'], label='Precision')
axs[0].plot(history['epoch'], history['metrics']['recall'], label='Recall')
axs[0].set_title('Precision & Recall')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Metric')
axs[0].legend()

# Виведення кривих втрат
axs[1].plot(history['epoch'], history['metrics']['loss'], label='Loss')
axs[1].set_title('Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()

plt.show()

# %%
# Використання моделі для прогнозування на нових зображеннях
img_path = '/content/dataset/test/image.jpg'  # Виберіть будь-яке зображення з тестової папки
results = model(img_path)  # Виконання детекції

# Виведення результатів на зображенні
results.show()  # Вивести зображення з нанесеними детекціями
